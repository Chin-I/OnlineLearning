# %%
#conda activate spacy
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
string = "Jane is an amazing guitarist"
doc = nlp(string)
pos = [(token.text, token.pos_) for token in doc]
print(pos)
# Out:
# [('Jane', 'PROPN'), ('is', 'AUX'), ('an', 'DET'), ('amazing', 'ADJ'), ('guitarist', 'NOUN')]

# %%
#Bear is NOUN
string = "The bear is a majestic animal"
doc = nlp(string)
pos = [(token.text, token.pos_) for token in doc]
for i in pos:
    print(i)
# Out:
# ('The', 'DET')
# ('bear', 'NOUN')
# ('is', 'AUX')
# ('a', 'DET')
# ('majestic', 'ADJ')
# ('animal', 'NOUN')

# %%
#Bear is VERB
string = "Please bear with me"
doc = nlp(string)
pos = [(token.text, token.pos_) for token in doc]
for i in pos:
    print(i)
# Out:
# ('Please', 'INTJ')
# ('bear', 'VERB')
# ('with', 'ADP')
# ('me', 'PRON')

# %%
def proper_nouns(text, model=nlp):
      # Create doc object
    doc = model(text)
    # Generate list of POS tags
    pos = [token.pos_ for token in doc]
    
    # Return number of proper nouns
    return pos.count("PROPN")

print(proper_nouns("Abdul, Bill and Cathy went to the market to buy apples.", nlp))
# Out:
# 3

# %%
# Returns number of other nouns
def nouns(text, model=nlp):
      # Create doc object
    doc = model(text)
    # Generate list of POS tags
    pos = [token.pos_ for token in doc]
    return pos.count("NOUN")
print(nouns("Abdul, Bill and Cathy went to the market to buy apples.", nlp))
# Out:
# 2

# %%
"""
headlins = 
(0, Unnamed: 0                               0
title         You Can Smell Hillary’s Fear
label                                 FAKE
num_propn                                3
num_noun                                 0
Name: 0, dtype: object)
(1, Unnamed: 0                                                    1
title         Watch The Exact Moment Paul Ryan Committed Pol...
label                                                      FAKE
num_propn                                                     9
num_noun                                                      1
Name: 1, dtype: object)
(2, Unnamed: 0                                              2
title         Kerry to go to Paris in gesture of sympathy
label                                                REAL
num_propn                                               2
num_noun                                                2
Name: 2, dtype: object)
(3, Unnamed: 0                                                    3
title         Bernie supporters on Twitter erupt in anger ag...
label                                                      FAKE
num_propn                                                     3
num_noun                                                      3
Name: 3, dtype: object)
(4, Unnamed: 0                                                   4
title         The Battle of New York: Why This Primary Matters
label                                                     REAL
num_propn                                                    3
num_noun                                                     0
Name: 4, dtype: object)
(5, Unnamed: 0              5
title         Tehran, USA
label                FAKE
num_propn               2
num_noun                0
Name: 5, dtype: object)
(6, Unnamed: 0                                                    6
title         Girl Horrified At What She Watches Boyfriend D...
label                                                      FAKE
num_propn                                                     2
num_noun                                                      2
Name: 6, dtype: object)
(7, Unnamed: 0                                    7
title         ‘Britain’s Schindler’ Dies at 106
label                                      REAL
num_propn                                     3
num_noun                                      0
Name: 7, dtype: object)
(8, Unnamed: 0                                                    8
title         Fact check: Trump and Clinton at the 'commande...
label                                                      REAL
num_propn                                                     2
num_noun                                                      5
Name: 8, dtype: object)
(9, Unnamed: 0                                                    9
title         Iran reportedly makes new push for uranium con...
label                                                      REAL
num_propn                                                     1
num_noun                                                      4
Name: 9, dtype: object)
(10, Unnamed: 0                                                   10
title         With all three Clintons in Iowa, a glimpse at ...
label                                                      REAL
num_propn                                                     4
num_noun                                                      3
Name: 10, dtype: object)
(11, Unnamed: 0                                                   11
title         Donald Trump’s Shockingly Weak Delegate Game S...
label                                                      REAL
num_propn                                                     7
num_noun                                                      0
Name: 11, dtype: object)
(12, Unnamed: 0                                                   12
title         Strong Solar Storm, Tech Risks Today | S0 News...
label                                                      FAKE
num_propn                                                     7
num_noun                                                      2
Name: 12, dtype: object)
(13, Unnamed: 0                                              13
title         10 Ways America Is Preparing for World War 3
label                                                 FAKE
num_propn                                                4
num_noun                                                 0
Name: 13, dtype: object)
(14, Unnamed: 0                                  14
title         Trump takes on Cruz, but lightly
label                                     REAL
num_propn                                    2
num_noun                                     0
Name: 14, dtype: object)
(15, Unnamed: 0                            15
title         How women lead differently
label                               REAL
num_propn                              0
num_noun                               1
Name: 15, dtype: object)
(16, Unnamed: 0                                                   16
title         Shocking! Michele Obama & Hillary Caught Glamo...
label                                                      FAKE
num_propn                                                     7
num_noun                                                      1
Name: 16, dtype: object)
(17, Unnamed: 0                                                   17
title         Hillary Clinton in HUGE Trouble After America ...
label                                                      FAKE
num_propn                                                    11
num_noun                                                      2
Name: 17, dtype: object)
(18, Unnamed: 0                                                   18
title         What's in that Iran bill that Obama doesn't like?
label                                                      REAL
num_propn                                                     2
num_noun                                                      2
Name: 18, dtype: object)
(19, Unnamed: 0                                                   19
title         The 1 chart that explains everything you need ...
label                                                      REAL
num_propn                                                     1
num_noun                                                      3
Name: 19, dtype: object)
(20, Unnamed: 0                                                   20
title         The slippery slope to Trump’s proposed ban on ...
label                                                      REAL
num_propn                                                     2
num_noun                                                      2
Name: 20, dtype: object)
(21, Unnamed: 0                                                   21
title         Episode #160 – SUNDAY WIRE: ‘Hail to the Deplo...
label                                                      FAKE
num_propn                                                     4
num_noun                                                      4
Name: 21, dtype: object)
(22, Unnamed: 0                                                   22
title         Hillary Clinton Makes A Bipartisan Appeal on S...
label                                                      REAL
num_propn                                                     5
num_noun                                                      1
Name: 22, dtype: object)
(23, Unnamed: 0                                                   23
title         New Senate majority leader’s main goal for GOP...
label                                                      REAL
num_propn                                                     3
num_noun                                                      3
Name: 23, dtype: object)
(24, Unnamed: 0                                       24
title         ‘Inferno’ and the Overpopulation Myth
label                                          FAKE
num_propn                                         3
num_noun                                          0
Name: 24, dtype: object)
(25, Unnamed: 0                                                   25
title         Anti-Trump forces seek last-ditch delegate revolt
label                                                      REAL
num_propn                                                     1
num_noun                                                      4
Name: 25, dtype: object)
(26, Unnamed: 0                                                   26
title         Sanders Trounces Clinton in W. Va. -- But Will...
label                                                      REAL
num_propn                                                     5
num_noun                                                      1
Name: 26, dtype: object)
(27, Unnamed: 0                                                   27
title         Donald Trump Is Changing His Campaign Slogan t...
label                                                      REAL
num_propn                                                     3
num_noun                                                      1
Name: 27, dtype: object)
(28, Unnamed: 0                                                   28
title         Pure chaos: Donald Trump’s campaign management...
label                                                      REAL
num_propn                                                     2
num_noun                                                      7
Name: 28, dtype: object)
(29, Unnamed: 0                                                   29
title         Syrian War Report – November 1, 2016: Syrian M...
label                                                      FAKE
num_propn                                                    10
num_noun                                                      0
Name: 29, dtype: object)
(30, Unnamed: 0                                30
title         GOP insiders: Carly crushed it
label                                   REAL
num_propn                                  1
num_noun                                   1
Name: 30, dtype: object)
(31, Unnamed: 0                                                   31
title         Jeffrey Sewell et al. : Metabiology face to fa...
label                                                      FAKE
num_propn                                                     6
num_noun                                                      3
Name: 31, dtype: object)
(32, Unnamed: 0                                            32
title         Why It’s Necessary To Relax Into A Stretch
label                                               FAKE
num_propn                                              1
num_noun                                               0
Name: 32, dtype: object)
(33, Unnamed: 0                                                   33
title         Brexit Encourages UK to Trade With Non-EU Stat...
label                                                      FAKE
num_propn                                                     7
num_noun                                                      0
Name: 33, dtype: object)
(34, Unnamed: 0                                                   34
title         2016 interview with Socrates: Another day of L...
label                                                      FAKE
num_propn                                                     2
num_noun                                                      6
Name: 34, dtype: object)
(35, Unnamed: 0                                                   35
title         Mike Pence Drapes Shawl Over Immodest Lady Jus...
label                                                      FAKE
num_propn                                                    11
num_noun                                                      1
Name: 35, dtype: object)
(36, Unnamed: 0                                              36
title         First Ever Hindu Woman Elected into Congress
label                                                 FAKE
num_propn                                                3
num_noun                                                 0
Name: 36, dtype: object)
(37, Unnamed: 0                                                   37
title         Donald Groped Hillary in 2005! Trump and Weine...
label                                                      FAKE
num_propn                                                     6
num_noun                                                      0
Name: 37, dtype: object)
(38, Unnamed: 0                                                   38
title         Ex-Assistant FBI Director: Clintons Are a Crim...
label                                                      FAKE
num_propn                                                     6
num_noun                                                      1
Name: 38, dtype: object)
(39, Unnamed: 0                                                   39
title         Hillary Wants Aggressively Interventionist For...
label                                                      FAKE
num_propn                                                     2
num_noun                                                      1
Name: 39, dtype: object)
(40, Unnamed: 0                                                   40
title         Both parties want to craft populist messages f...
label                                                      REAL
num_propn                                                     0
num_noun                                                      2
Name: 40, dtype: object)
(41, Unnamed: 0                                                   41
title         First Take: Wall Street bids goodbye to June hike
label                                                      REAL
num_propn                                                     3
num_noun                                                      3
Name: 41, dtype: object)
(42, Unnamed: 0                                                   42
title         Real Disclosure! Secret Alien Base Found In Mo...
label                                                      FAKE
num_propn                                                     8
num_noun                                                      0
Name: 42, dtype: object)
(43, Unnamed: 0                                                   43
title         Homeless Woman Protects Trump’s Walk of Fame S...
label                                                      FAKE
num_propn                                                     5
num_noun                                                      2
Name: 43, dtype: object)
(44, Unnamed: 0                                                   44
title         With 3:20 a.m. tweet storm Saturday, Clinton c...
label                                                      REAL
num_propn                                                     4
num_noun                                                      4
Name: 44, dtype: object)
(45, Unnamed: 0                                                   45
title         220 ‘Significant’ Pipeline Spills Already This...
label                                                      FAKE
num_propn                                                     7
num_noun                                                      0
Name: 45, dtype: object)
(46, Unnamed: 0                                                   46
title         Obama makes the right call to tough it out in ...
label                                                      REAL
num_propn                                                     2
num_noun                                                      1
Name: 46, dtype: object)
(47, Unnamed: 0                                                   47
title         Senate race rankings: Dems attack as GOP lays ...
label                                                      REAL
num_propn                                                     2
num_noun                                                      7
Name: 47, dtype: object)
(48, Unnamed: 0                                                   48
title         ‘He didn’t know the boy didn’t want to be rape...
label                                                      FAKE
num_propn                                                     1
num_noun                                                      6
Name: 48, dtype: object)
(49, Unnamed: 0                                                   49
title         Pieczenik “Rogue FBI Agents and Wikileaks are ...
label                                                      FAKE
num_propn                                                    10
num_noun                                                      0
Name: 49, dtype: object)
(50, Unnamed: 0                                                 50
title         American politics has reached peak polarization
label                                                    REAL
num_propn                                                   0
num_noun                                                    2
Name: 50, dtype: object)
(51, Unnamed: 0                                                   51
title         Anti-Muhammad cartoon contest: Free speech or ...
label                                                      REAL
num_propn                                                     1
num_noun                                                      4
Name: 51, dtype: object)
(52, Unnamed: 0                                                   52
title         3 Effects of Substance Abuse on Individual, Fa...
label                                                      FAKE
num_propn                                                     6
num_noun                                                      0
Name: 52, dtype: object)
(53, Unnamed: 0                                                   53
title         Tree Shaped Vertical Farms That Grow 24 Acres ...
label                                                      FAKE
num_propn                                                     5
num_noun                                                      1
Name: 53, dtype: object)
(54, Unnamed: 0                                      54
title         New Comment Features have been Added
label                                         FAKE
num_propn                                        0
num_noun                                         2
Name: 54, dtype: object)
(55, Unnamed: 0                                            55
title         World's newspapers react to 'Hebdo' attack
label                                               REAL
num_propn                                              2
num_noun                                               2
Name: 55, dtype: object)
(56, Unnamed: 0                                            56
title         Ying and Yang (the Gold and Silver Set-Up)
label                                               FAKE
num_propn                                              5
num_noun                                               1
Name: 56, dtype: object)
(57, Unnamed: 0                                       57
title         Closed primaries, 'warped' democracy?
label                                          REAL
num_propn                                         0
num_noun                                          2
Name: 57, dtype: object)
(58, Unnamed: 0                                                   58
title         Police Turn In Badges Rather Than Incite Viole...
label                                                      FAKE
num_propn                                                     5
num_noun                                                      2
Name: 58, dtype: object)
(59, Unnamed: 0                                                   59
title         Donald Trump: Hillary Clinton has 'caused trem...
label                                                      REAL
num_propn                                                     4
num_noun                                                      1
Name: 59, dtype: object)
(60, Unnamed: 0                                                   60
title         Detroit women’s Halloween decorations depict ‘...
label                                                      FAKE
num_propn                                                     2
num_noun                                                      7
Name: 60, dtype: object)
(61, Unnamed: 0                                             61
title         Biden makes another surprise political stop
label                                                REAL
num_propn                                               1
num_noun                                                2
Name: 61, dtype: object)
(62, Unnamed: 0                                                   62
title         Hillary Clinton's declining favorability numbe...
label                                                      REAL
num_propn                                                     2
num_noun                                                      3
Name: 62, dtype: object)
(63, Unnamed: 0                                                   63
title         Comment on Quid Pro Quo? Wikileaks Email Revea...
label                                                      FAKE
num_propn                                                    11
num_noun                                                      2
Name: 63, dtype: object)
(64, Unnamed: 0                                                   64
title         Hillary Clinton: The criminal investigation ke...
label                                                      REAL
num_propn                                                     2
num_noun                                                      1
Name: 64, dtype: object)
(65, Unnamed: 0                               65
title         Rubio’s parting shot at Trump
label                                  REAL
num_propn                                 2
num_noun                                  1
Name: 65, dtype: object)
(66, Unnamed: 0                                                   66
title         Loretta Lynch becomes first African-American w...
label                                                      REAL
num_propn                                                     3
num_noun                                                      1
Name: 66, dtype: object)
(67, Unnamed: 0                                                   67
title         Why it's funny Republicans are upset with Face...
label                                                      REAL
num_propn                                                     2
num_noun                                                      1
Name: 67, dtype: object)
(68, Unnamed: 0                                                   68
title         FBI checking if Orlando shooter's wife knew at...
label                                                      REAL
num_propn                                                     2
num_noun                                                      5
Name: 68, dtype: object)
(69, Unnamed: 0                                               69
title         Is google and YouTube in the Hillary's purse?
label                                                  FAKE
num_propn                                                 3
num_noun                                                  1
Name: 69, dtype: object)
(70, Unnamed: 0                                                70
title         Handicapping the Hispanic vote for 2016 GOPers
label                                                   REAL
num_propn                                                  0
num_noun                                                   2
Name: 70, dtype: object)
(71, Unnamed: 0                                            71
title         Truth Will Out Radio: The Laconia Incident
label                                               FAKE
num_propn                                              4
num_noun                                               1
Name: 71, dtype: object)
(72, Unnamed: 0                                                   72
title         GOP establishment nightmare? Ted Cruz vs. Dona...
label                                                      REAL
num_propn                                                     5
num_noun                                                      2
Name: 72, dtype: object)
(73, Unnamed: 0                                                   73
title         Bernie Sanders lost poor voters in South Carol...
label                                                      REAL
num_propn                                                     4
num_noun                                                      4
Name: 73, dtype: object)
(74, Unnamed: 0                     74
title         Should I Get Botox?
label                        FAKE
num_propn                       1
num_noun                        0
Name: 74, dtype: object)
(75, Unnamed: 0                                                   75
title         Jeb Bush Picks Up Endorsement From Lindsey Graham
label                                                      REAL
num_propn                                                     5
num_noun                                                      1
Name: 75, dtype: object)
(76, Unnamed: 0                                                   76
title         2016 Republican race enters a new, volatile phase
label                                                      REAL
num_propn                                                     0
num_noun                                                      2
Name: 76, dtype: object)
(77, Unnamed: 0                                            77
title         ‘Hands up, don’t shoot’ was built on a lie
label                                               REAL
num_propn                                              0
num_noun                                               2
Name: 77, dtype: object)
(78, Unnamed: 0                                            78
title         Lavrov and Kerry discuss Syrian settlement
label                                               FAKE
num_propn                                              2
num_noun                                               1
Name: 78, dtype: object)
(79, Unnamed: 0                                                   79
title         BREAKING : DOJ Says They Will “HELP” Review th...
label                                                      FAKE
num_propn                                                     4
num_noun                                                      0
Name: 79, dtype: object)
(80, Unnamed: 0                                                   80
title         Bernie Sanders' call for ouster of two convent...
label                                                      REAL
num_propn                                                     2
num_noun                                                      5
Name: 80, dtype: object)
(81, Unnamed: 0                                                   81
title         Five Reasons the New York Democratic Primary F...
label                                                      REAL
num_propn                                                     5
num_noun                                                      1
Name: 81, dtype: object)
(82, Unnamed: 0                                                   82
title         To get around Congress, Obama turns to city halls
label                                                      REAL
num_propn                                                     2
num_noun                                                      2
Name: 82, dtype: object)
(83, Unnamed: 0                                                   83
title         Celebrity Deathmatch: Darkmoon Sages Make Thei...
label                                                      FAKE
num_propn                                                     7
num_noun                                                      1
Name: 83, dtype: object)
(84, Unnamed: 0                                           84
title         John Kerry: ISIS responsible for genocide
label                                              REAL
num_propn                                             3
num_noun                                              1
Name: 84, dtype: object)
(85, Unnamed: 0                                                   85
title         Mitt Romney's Re-Invention As Anti-Poverty War...
label                                                      REAL
num_propn                                                     5
num_noun                                                      1
Name: 85, dtype: object)
(86, Unnamed: 0                                      86
title         King: Fill the Supreme Court vacancy
label                                         REAL
num_propn                                        2
num_noun                                         2
Name: 86, dtype: object)
(87, Unnamed: 0                                                   87
title         Ted Cruz is toast: It’s not just that he won’t...
label                                                      REAL
num_propn                                                     3
num_noun                                                      3
Name: 87, dtype: object)
(88, Unnamed: 0                                                   88
title         Obama’s speech in Selma was an answer to those...
label                                                      REAL
num_propn                                                     3
num_noun                                                      4
Name: 88, dtype: object)
(89, Unnamed: 0                                         89
title         Where Does Bernie Sanders Go From Here?
label                                            REAL
num_propn                                           2
num_noun                                            0
Name: 89, dtype: object)
(90, Unnamed: 0                                                  90
title         Exclusive: GOP campaigns plot revolt against RNC
label                                                     REAL
num_propn                                                    3
num_noun                                                     2
Name: 90, dtype: object)
(91, Unnamed: 0                                                   91
title         Revelation Unleashed: Unlocking The Mysteries ...
label                                                      FAKE
num_propn                                                     5
num_noun                                                      0
Name: 91, dtype: object)
(92, Unnamed: 0                                                   92
title         Silent Counter-Coup by 17 Intel Agencies To St...
label                                                      FAKE
num_propn                                                     6
num_noun                                                      1
Name: 92, dtype: object)
(93, Unnamed: 0                                                   93
title         Why Hillary Clinton, not Bernie Sanders, 'won'...
label                                                      REAL
num_propn                                                     4
num_noun                                                      2
Name: 93, dtype: object)
(94, Unnamed: 0                                                   94
title         French police hunt two brothers accused of Cha...
label                                                      REAL
num_propn                                                     2
num_noun                                                      5
Name: 94, dtype: object)
(95, Unnamed: 0                                                   95
title         The Mandela Effect was made by one overlooked ...
label                                                      FAKE
num_propn                                                     2
num_noun                                                      5
Name: 95, dtype: object)
(96, Unnamed: 0                                                   96
title         CNN: One voter can make a difference by voting...
label                                                      FAKE
num_propn                                                     1
num_noun                                                      2
Name: 96, dtype: object)
(97, Unnamed: 0                                                   97
title         Give Social Security recipients a CEO-style raise
label                                                      REAL
num_propn                                                     2
num_noun                                                      4
Name: 97, dtype: object)
(98, Unnamed: 0                                                   98
title         Fireworks erupt between Trump and Bush, Rubio ...
label                                                      REAL
num_propn                                                     5
num_noun                                                      2
Name: 98, dtype: object)
(99, Unnamed: 0                                                   99
title         Obama, sounding like his critics, admits no 'c...
label                                                      REAL
num_propn                                                     2
num_noun                                                      2
Name: 99, dtype: object)
"""

# %%
# Noun usage in fake news
headlines['num_propn'] = headlines['title'].apply(proper_nouns)
headlines['num_noun'] = headlines['title'].apply(nouns)

# Compute mean of proper nouns
real_propn = headlines[headlines['label'] == 'REAL']['num_propn'].mean()
fake_propn = headlines[headlines['label'] == 'FAKE']['num_propn'].mean()

# Compute mean of other nouns
real_noun = headlines[headlines['label'] == 'REAL']['num_noun'].mean()
fake_noun = headlines[headlines['label'] == 'FAKE']['num_noun'].mean()

# Print results
print("Mean no. of proper nouns in real and fake headlines are %.2f and %.2f respectively"%(real_propn, fake_propn))
print("Mean no. of other nouns in real and fake headlines are %.2f and %.2f respectively"%(real_noun, fake_noun))

# %%
"""
<script.py> output:
    Mean no. of proper nouns in real headlines are 2.46 
                         and in fake headlines 4.86 respectively
    Mean no. of other nouns in real headlines are 2.3 
                        and in fake headlines are 1.44 respectively
"""
